# %% [markdown]
# <a href="https://colab.research.google.com/github/Basu8971/Materraproject/blob/main/%20DOS%2C%20irrigation%2C%20growingdays%20and%20yield%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install necessary libraries (if not already installed)
# !pip install --upgrade gspread google-auth pandas matplotlib seaborn

# Step 2: Authenticate with Google using google-auth
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Authenticate the Google account
auth.authenticate_user()

# Use google-auth to get credentials and authorize gspread
creds, _ = default()
gc = gspread.authorize(creds)

# Step 3: Access Google Sheets using URLs
sheet_url = 'https://docs.google.com/spreadsheets/d/1hzlVvQIKfDp4J1CsZvSS1EOGqKZrihj4jm--w6QftT4/edit?gid=1261462149#gid=1261462149'

# Open the Google Sheets using gspread
sheet = gc.open_by_url(sheet_url)

# Load the data from the sheet into a DataFrame
data = pd.DataFrame(sheet.sheet1.get_all_records())

# Step 4: Check and Clean the Column Names
data.columns = data.columns.str.strip()  # Strip extra spaces if any

# Step 5: Convert 'DOS' and 'DOH' to datetime (DD/MM/YYYY format)
data['DOS'] = pd.to_datetime(data['DOS'], format='%d/%m/%Y', errors='coerce')
data['DOH'] = pd.to_datetime(data['DOH'], format='%d/%m/%Y', errors='coerce')

# Step 6: Yield Classification (We will assign categories)
def yield_category(yield_value):
    if yield_value <= 100:
        return '0-100'
    elif yield_value <= 200:
        return '100-200'
    elif yield_value <= 300:
        return '200-300'
    elif yield_value <= 500:
        return '300-500'
    elif yield_value <= 700:
        return '500-700'
    elif yield_value <= 1000:
        return '700-1000'
    else:
        return 'Above 1000'

# Step 7: Add the yield category column
data['Yield Category'] = data['Yield'].apply(yield_category)

# Step 8: Filter the data for YES and NO irrigation groups using .loc to avoid SettingWithCopyWarning
yes_irrigation = data.loc[data['Irrigation'] == 'YES'].copy()
no_irrigation = data.loc[data['Irrigation'] == 'NO'].copy()

# Step 9: Assign 'Irrigation Status' for both YES and NO
yes_irrigation['Irrigation Status'] = 'YES'
no_irrigation['Irrigation Status'] = 'NO'

# Combine them for the plot
combined_data = pd.concat([yes_irrigation, no_irrigation])

# Step 10: Convert DOS and DOH to numeric (for plotting), as boxplots require numeric values
combined_data['DOS_numeric'] = combined_data['DOS'].apply(lambda x: (x - pd.Timestamp('1970-01-01')).days if pd.notna(x) else None)
combined_data['DOH_numeric'] = combined_data['DOH'].apply(lambda x: (x - pd.Timestamp('1970-01-01')).days if pd.notna(x) else None)

# Step 11: Sort the Yield Categories in linear order
category_order = ['0-100', '100-200', '200-300', '300-500', '500-700', '700-1000', 'Above 1000']
combined_data['Yield Category'] = pd.Categorical(combined_data['Yield Category'], categories=category_order, ordered=True)

# Step 12: Create separate box plots for each location and irrigation status
locations = combined_data['Location'].unique()  # Get unique locations

for location in locations:
    # Filter the data for the current location
    location_data = combined_data[combined_data['Location'] == location]

    # DOS Plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Yield Category', y='DOS_numeric', hue='Irrigation Status', data=location_data, palette="Set2", showfliers=False)

    # Calculate the medians for each category (ignoring hue)
    medians_yes_dos = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOS_numeric'].median()
    medians_no_dos = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOS_numeric'].median()

    # Draw a line connecting the medians for YES and NO
    plt.plot(medians_yes_dos.index, medians_yes_dos.values, marker='o', color='black', linestyle='-', linewidth=2, markersize=8, label='YES Irrigation (Median)')
    plt.plot(medians_no_dos.index, medians_no_dos.values, marker='o', color='red', linestyle='--', linewidth=2, markersize=8, label='NO Irrigation (Median)')

    # Set labels and title for DOS plot
    plt.title(f'Date of Sowing (DOS) by Yield Category, Irrigation Status, and Location: {location}')
    plt.xlabel('Yield Category')
    plt.ylabel('Date of Sowing (DOS)')

    # Convert the y-axis back to date format
    ticks_dos = plt.gca().get_yticks()
    plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_dos])

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.legend()

    # Show the plot for DOS
    plt.show()

    # DOH Plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Yield Category', y='DOH_numeric', hue='Irrigation Status', data=location_data, palette="Set1", showfliers=False)

    # Calculate the medians for each category (ignoring hue)
    medians_yes_doh = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOH_numeric'].median()
    medians_no_doh = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOH_numeric'].median()

    # Draw a line connecting the medians for YES and NO
    plt.plot(medians_yes_doh.index, medians_yes_doh.values, marker='o', color='black', linestyle='-', linewidth=2, markersize=8, label='YES Irrigation (Median)')
    plt.plot(medians_no_doh.index, medians_no_doh.values, marker='o', color='red', linestyle='--', linewidth=2, markersize=8, label='NO Irrigation (Median)')

    # Set labels and title for DOH plot
    plt.title(f'Date of Harvest (DOH) by Yield Category, Irrigation Status, and Location: {location}')
    plt.xlabel('Yield Category')
    plt.ylabel('Date of Harvest (DOH)')

    # Convert the y-axis back to date format
    ticks_doh = plt.gca().get_yticks()
    plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_doh])

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.legend()

    # Show the plot for DOH
    plt.show()

    # Growing Days Plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Yield Category', y='Growingdays', hue='Irrigation Status', data=location_data, palette="Set3", showfliers=False)

    # Calculate the medians for each category (ignoring hue)
    medians_yes_gd = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['Growingdays'].median()
    medians_no_gd = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['Growingdays'].median()

    # Draw a line connecting the medians for YES and NO
    plt.plot(medians_yes_gd.index, medians_yes_gd.values, marker='o', color='black', linestyle='-', linewidth=2, markersize=8, label='YES Irrigation (Median)')
    plt.plot(medians_no_gd.index, medians_no_gd.values, marker='o', color='red', linestyle='--', linewidth=2, markersize=8, label='NO Irrigation (Median)')

    # Set labels and title for Growing Days plot
    plt.title(f'Growing Days by Yield Category, Irrigation Status, and Location: {location}')
    plt.xlabel('Yield Category')
    plt.ylabel('Growing Days')

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.legend()

    # Show the plot for Growing Days
    plt.show()

    # Print the result for each location
    print(f"Data for Location: {location}")
    print(location_data[['FarmerName', 'DOS', 'DOH', 'Yield', 'Location', 'Irrigation', 'Yield Category', 'Growingdays']].head())  # Print the relevant data
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.1.4)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (2.37.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth) (4.9)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.12.14)
# <ipython-input-69-9abf4ae16083>:86: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_dos = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:87: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_dos = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_dos])
# <ipython-input-69-9abf4ae16083>:114: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_doh = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_doh = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:128: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_doh])
# <ipython-input-69-9abf4ae16083>:142: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_gd = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['Growingdays'].median()
# <ipython-input-69-9abf4ae16083>:143: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_gd = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['Growingdays'].median()
# Data for Location: Grambharati
#                         FarmerName        DOS        DOH  Yield     Location  \
# 0  Dineshbhai Baldevbhai Choudhury 2023-06-06 2023-10-30  544.0  Grambharati
# 1        Vishnubhai Atmaram Thakor 2023-05-31 2023-11-25  792.0  Grambharati
# 2   Dineshbhai Gandabhai Chaudhari 2023-06-05 2023-10-19  120.0  Grambharati
# 3         Harisinh Laxmansinh Rana 2023-06-02 2023-11-04  480.0  Grambharati
# 4     Vikramsinh Parbatsinh Vagela 2023-06-09 2023-10-27  344.0  Grambharati
#
#   Irrigation Yield Category  Growingdays
# 0        YES        500-700          146
# 1        YES       700-1000          178
# 2        YES        100-200          136
# 3        YES        300-500          155
# 4        YES        300-500          140
# <ipython-input-69-9abf4ae16083>:86: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_dos = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:87: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_dos = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_dos])
# <ipython-input-69-9abf4ae16083>:114: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_doh = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_doh = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:128: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_doh])
# <ipython-input-69-9abf4ae16083>:142: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_gd = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['Growingdays'].median()
# <ipython-input-69-9abf4ae16083>:143: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_gd = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['Growingdays'].median()
# Data for Location: Jalna
#                      FarmerName        DOS        DOH   Yield Location  \
# 125    Nivrutti Ranganath Ghule 2023-06-22 2023-12-29   950.0    Jalna
# 126      Rangnath Narayan Ghule 2023-06-22 2023-11-26  7001.0    Jalna
# 355  Dashrath Vishvanath Khaire 2023-06-14 2023-12-04  1000.0    Jalna
# 389     Bhagwat Nanabhau Dongre 2023-06-20 2023-12-20   700.0    Jalna
# 390        Ramkala Datta Dongre 2023-06-26 2024-01-13   900.0    Jalna
#
#     Irrigation Yield Category  Growingdays
# 125        YES       700-1000          190
# 126        YES     Above 1000          157
# 355        YES       700-1000          173
# 389        YES        500-700          183
# 390        YES       700-1000          201
# <ipython-input-69-9abf4ae16083>:86: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_dos = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:87: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_dos = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_dos])
# <ipython-input-69-9abf4ae16083>:114: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_doh = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_doh = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:128: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_doh])
# <ipython-input-69-9abf4ae16083>:142: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_gd = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['Growingdays'].median()
# <ipython-input-69-9abf4ae16083>:143: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_gd = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['Growingdays'].median()
# Data for Location: Jambusar
#                         FarmerName        DOS        DOH  Yield  Location  \
# 359              Rajubhai 0 Rabari 2023-06-15 2023-11-02  300.0  Jambusar
# 378  Sureshbhai Sedhabhai Chodhary 2023-06-06 2023-10-27  520.0  Jambusar
# 403       Vanrajsinh Devuji Chavda 2023-06-09 2023-10-31  200.0  Jambusar
# 424       Bhadresh Ramanbhai Patel 2023-06-26 2024-02-01  341.0  Jambusar
# 628            Arjun Devrao Ingole 2023-06-28 2023-12-17  530.0  Jambusar
#
#     Irrigation Yield Category  Growingdays
# 359        YES        200-300          140
# 378        YES        500-700          143
# 403        YES        100-200          144
# 424        YES        300-500          220
# 628        YES        500-700          172
# <ipython-input-69-9abf4ae16083>:86: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_dos = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:87: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_dos = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOS_numeric'].median()
# <ipython-input-69-9abf4ae16083>:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_dos])
# <ipython-input-69-9abf4ae16083>:114: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_doh = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_doh = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['DOH_numeric'].median()
# <ipython-input-69-9abf4ae16083>:128: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([pd.to_datetime(tick, unit='D', origin='1970-01-01').strftime('%Y-%m-%d') for tick in ticks_doh])
# <ipython-input-69-9abf4ae16083>:142: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_yes_gd = location_data[location_data['Irrigation Status'] == 'YES'].groupby('Yield Category')['Growingdays'].median()
# <ipython-input-69-9abf4ae16083>:143: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians_no_gd = location_data[location_data['Irrigation Status'] == 'NO'].groupby('Yield Category')['Growingdays'].median()
# Data for Location: #N/A
#                        FarmerName        DOS        DOH  Yield Location  \
# 421  Bhikhusinh Gaabhusinh Rathod 2023-06-06 2023-10-30  300.0     #N/A
# 853       Ajayji Natavarji Thakor 2023-05-22 2023-11-28  100.0     #N/A
# 833     Lataben Udesangbhai Jadav 2023-07-01 2024-01-20  340.0     #N/A
#
#     Irrigation Yield Category  Growingdays
# 421        YES        200-300          146
# 853        YES          0-100          190
# 833         NO        300-500          203
